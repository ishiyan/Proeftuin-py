# %%
import numpy as np
import pandas as pd
import gymnasium as gym

from env.environments import TradingEnv

# %% [markdown]
# ## Read training data

# %%
def read_adjusted_history_ohlcv(path_csv):
    history = pd.read_csv(path_csv, parse_dates=["Date"], index_col='Date', \
        dtype={'Open': float, 'High': float, 'Low': float, 'Close': float,'Volume': float})
    history = history.rename(columns={'Open': 'open', 'High': 'high', 'Low': 'low', 'Close': 'close', 'Volume': 'volume'})
    history.sort_index(inplace= True)
    history.dropna(inplace= True)
    history.drop_duplicates(inplace=True)
    return history

price_history = read_adjusted_history_ohlcv('yfinance/ibm.1d.adjusted.csv')
price_history
# Out:
#                                  open        high         low       close  \
# Date
# 1962-01-02 00:00:00-05:00    1.543904    1.543904    1.526557    1.526557
# 1962-01-03 00:00:00-05:00    1.526556    1.539900    1.526556    1.539900
# 1962-01-04 00:00:00-05:00    1.539900    1.539900    1.523888    1.524555
# 1962-01-05 00:00:00-05:00    1.522554    1.522554    1.491862    1.494531
# 1962-01-08 00:00:00-05:00    1.493197    1.493197    1.454499    1.466509
# ...                               ...         ...         ...         ...
# 2024-05-13 00:00:00-04:00  167.500000  168.059998  166.759995  167.559998
# 2024-05-14 00:00:00-04:00  167.860001  168.130005  166.479996  167.360001
# 2024-05-15 00:00:00-04:00  167.940002  168.350006  167.339996  168.259995
# 2024-05-16 00:00:00-04:00  168.259995  169.630005  167.789993  168.970001
# 2024-05-17 00:00:00-04:00  168.970001  169.110001  167.330002  169.029999
#
#                                  volume
# Date
# 1962-01-02 00:00:00-05:00  1.948437e+06
# 1962-01-03 00:00:00-05:00  1.461328e+06
# 1962-01-04 00:00:00-05:00  1.311448e+06
# 1962-01-05 00:00:00-05:00  1.836027e+06
# 1962-01-08 00:00:00-05:00  2.735306e+06
# ...                                 ...
# 2024-05-13 00:00:00-04:00  2.414900e+06
# 2024-05-14 00:00:00-04:00  2.601000e+06
# 2024-05-15 00:00:00-04:00  4.468800e+06
# 2024-05-16 00:00:00-04:00  3.492300e+06
# 2024-05-17 00:00:00-04:00  2.954100e+06
#
# [15700 rows x 5 columns]

# %% [markdown]
# ## Generate features

# %%
price_history['median'] = (price_history['high'] + price_history['low']) / 2
price_history['typical'] = (price_history['high'] + price_history['low'] + price_history['close']) / 3

price_history["feature_open"] = price_history["open"]/price_history["close"]
price_history["feature_high"] = price_history["high"]/price_history["close"]
price_history["feature_low"] = price_history["low"]/price_history["close"]
price_history["feature_close"] = price_history["close"].pct_change()
price_history["feature_volume"] = price_history["volume"] / price_history["volume"].rolling(252).max()

price_history.dropna(inplace= True)
price_history
# Out:
#                                  open        high         low       close  \
# Date
# 1962-12-31 00:00:00-05:00    1.048241    1.054250    1.040229    1.041564
# 1963-01-02 00:00:00-05:00    1.041564    1.041564    1.026208    1.027543
# 1963-01-03 00:00:00-05:00    1.029547    1.058924    1.029547    1.058924
# 1963-01-04 00:00:00-05:00    1.060259    1.070274    1.060259    1.060259
# 1963-01-07 00:00:00-05:00    1.060259    1.070274    1.049577    1.051580
# ...                               ...         ...         ...         ...
# 2024-05-13 00:00:00-04:00  167.500000  168.059998  166.759995  167.559998
# 1963-01-21 00:00:00-05:00      1.000000     0.986715       0.003636
#
#                            feature_volume
# Date
# 1962-12-31 00:00:00-05:00        0.157063
# 1963-01-02 00:00:00-05:00        0.357879
# 1963-01-03 00:00:00-05:00        0.168282
# 1963-01-04 00:00:00-05:00        0.229985
# 1963-01-07 00:00:00-05:00        0.132382
# 1963-01-08 00:00:00-05:00        0.270372
# 1963-01-09 00:00:00-05:00        0.286079
# 1963-01-10 00:00:00-05:00        0.232229
# 1963-01-11 00:00:00-05:00        0.201938
# 1963-01-14 00:00:00-05:00        0.370220
# 1963-01-15 00:00:00-05:00        0.311882
# 1963-01-16 00:00:00-05:00        0.189597
# 1963-01-17 00:00:00-05:00        0.181744
# 1963-01-18 00:00:00-05:00        0.127894
# 1963-01-21 00:00:00-05:00        0.131260

# %% [markdown]
# ## Run

# %%
# Create your own reward function with the history object
def reward_function(history):
    return np.log(history["portfolio_valuation", -1] / history["portfolio_valuation", -2]) #log (p_t / p_t-1 )

env = gym.make(
        "TradingEnv-v0",
#env = TradingEnv(
        name= "environment test",
        df = price_history,
        price_column_name = 'typical',
        windows= 3,
        positions = [0, 1], # From -1 (=SHORT), to +1 (=LONG)
        initial_position = 0, #'random', #Initial position
        trading_fees = 0.01/100, # 0.01% per stock buy / sell
        borrow_interest_rate= 0.0003/100, #per timestep (= 1h here)
        reward_function = reward_function,
        portfolio_initial_value = 1000, # in FIAT (here, USD)
        max_episode_duration = 'max', #500,
    )

env.add_metric('Position Changes', lambda history : np.sum(np.diff(history['position']) != 0) )
env.add_metric('Episode Lenght', lambda history : len(history['position']) )

done, truncated = False, False
observation, info = env.reset()
print('info', info)
print('observation', observation)
while not done and not truncated:
    action = env.action_space.sample()
    observation, reward, done, truncated, info = env.step(action)
    print('done, truncated, action, reward', done, truncated, action, reward)
    print('info', info)
    print('observation', observation)
# Save for render
# env.save_for_render()
# Out:
# info {'idx': 2, 'step': 0, 'date': Timestamp('1963-01-03 00:00:00-0500', tz='UTC-05:00'), 'position_index': 0, 'position': 0, 'real_position': 0, 'data_typical': 1.0491317002355418, 'data_median': 1.0442354512779952, 'data_high': 1.0589241981506348, 'data_low': 1.0295467044053557, 'data_open': 1.0295467044053557, 'data_volume': 5616549.630300916, 'data_close': 1.0589241981506348, 'portfolio_valuation': 1000.0, 'portfolio_distribution_asset': 0, 'portfolio_distribution_fiat': 1000.0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0, 'portfolio_distribution_interest_fiat': 0, 'reward': 0}
# observation [[ 1.0064104   1.0121794   0.99871796 -0.00636941  0.15706289  0.
#    0.        ]
#  [ 1.0136452   1.0136452   0.9987004  -0.01346186  0.35787916  0.
#    0.        ]
#  [ 0.97225726  1.          0.97225726  0.03053997  0.16828163  0.
#    0.        ]]
# done, truncated, action, reward False False 0 0.0
# info {'idx': 3, 'step': 1, 'date': Timestamp('1963-01-04 00:00:00-0500', tz='UTC-05:00'), 'position_index': 0, 'position': 0, 'real_position': 0.0, 'data_typical': 1.0635970834755708, 'data_median': 1.0652662521397784, 'data_high': 1.070273758132401, 'data_low': 1.0602587461471558, 'data_open': 1.0602587461471558, 'data_volume': 7675956.045016385, 'data_close': 1.0602587461471558, 'portfolio_valuation': 1000.0, 'portfolio_distribution_asset': 0, 'portfolio_distribution_fiat': 1000.0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': 0.0}
# observation [[ 1.0136452   1.0136452   0.9987004  -0.01346186  0.35787916  0.
#    0.        ]
#  [ 0.97225726  1.          0.97225726  0.03053997  0.16828163  0.
#    0.        ]
#  [ 1.          1.0094458   1.          0.00126029  0.22998504  0.
#    0.        ]]
# done, truncated, action, reward False False 1 -0.006186066744446253
# info {'idx': 4, 'step': 2, 'date': Timestamp('1963-01-07 00:00:00-0500', tz='UTC-05:00'), 'position_index': 1, 'position': 1, 'real_position': 1.0, 'data_typical': 1.0571436239509904, 'data_median': 1.05992557901578, 'data_high': 1.0702744278797374, 'data_low': 1.0495767301518228, 'data_open': 1.060259409627378, 'data_volume': 4418352.422006305, 'data_close': 1.0515797138214111, 'portfolio_valuation': 993.8330275732407, 'portfolio_distribution_asset': 940.1116414616101, 'portfolio_distribution_fiat': 0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': -0.006186066744446253}
# observation [[ 0.97225726  1.          0.97225726  0.03053997  0.16828163  0.
#    0.        ]
#  [ 1.          1.0094458   1.          0.00126029  0.22998504  0.
#    0.        ]
#  [ 1.0082539   1.0177778   0.9980953  -0.00818577  0.13238154  1.
#    1.        ]]
# done, truncated, action, reward False False 1 0.013799105710461012
# info {'idx': 5, 'step': 3, 'date': Timestamp('1963-01-08 00:00:00-0500', tz='UTC-05:00'), 'position_index': 1, 'position': 1, 'real_position': 1.0, 'data_typical': 1.0718323732919848, 'data_median': 1.0689391412596936, 'data_high': 1.0776188373565674, 'data_low': 1.0602594451628196, 'data_open': 1.0602594451628196, 'data_volume': 9023922.864534996, 'data_close': 1.0776188373565674, 'portfolio_valuation': 1007.6420918272211, 'portfolio_distribution_asset': 940.1116414616101, 'portfolio_distribution_fiat': 0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': 0.013799105710461012}
# observation [[ 1.          1.0094458   1.          0.00126029  0.22998504  0.
#    0.        ]
#  [ 1.0082539   1.0177778   0.9980953  -0.00818577  0.13238154  1.
#    1.        ]
#  [ 0.98389095  1.          0.98389095  0.02476191  0.27037248  1.
#    1.        ]]
# done, truncated, action, reward False False 0 -0.00010000500033334732
# info {'idx': 6, 'step': 4, 'date': Timestamp('1963-01-09 00:00:00-0500', tz='UTC-05:00'), 'position_index': 0, 'position': 0, 'real_position': 0.0, 'data_typical': 1.0793987005962533, 'data_median': 1.0799550846239332, 'data_high': 1.088300845039132, 'data_low': 1.0716093242087346, 'data_open': 1.0776181718033184, 'data_volume': 9548140.04834324, 'data_close': 1.0782859325408936, 'portfolio_valuation': 1007.5413276180384, 'portfolio_distribution_asset': 0, 'portfolio_distribution_fiat': 1007.5413276180384, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': -0.00010000500033334732}
# observation [[ 1.0082539e+00  1.0177778e+00  9.9809527e-01 -8.1857685e-03
#    1.3238154e-01  1.0000000e+00  1.0000000e+00]
#  [ 9.8389095e-01  1.0000000e+00  9.8389095e-01  2.4761911e-02
#    2.7037248e-01  1.0000000e+00  1.0000000e+00]
#  [ 9.9938071e-01  1.0092878e+00  9.9380815e-01  6.1904558e-04
#    2.8607893e-01  0.0000000e+00  0.0000000e+00]]
# done, truncated, action, reward False False 1 0.006271695732777699
# info {'idx': 7, 'step': 5, 'date': Timestamp('1963-01-10 00:00:00-0500', tz='UTC-05:00'), 'position_index': 1, 'position': 1, 'real_position': 1.0, 'data_typical': 1.0862982637211882, 'data_median': 1.086632127542079, 'data_high': 1.0923073462767352, 'data_low': 1.080956908807423, 'data_open': 1.080956908807423, 'data_volume': 7750840.710814809, 'data_close': 1.0856305360794067, 'portfolio_valuation': 1013.8801771530804, 'portfolio_distribution_asset': 933.3349882010906, 'portfolio_distribution_fiat': 0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': 0.006271695732777699}
# observation [[9.8389095e-01 1.0000000e+00 9.8389095e-01 2.4761911e-02 2.7037248e-01
#   1.0000000e+00 1.0000000e+00]
#  [9.9938071e-01 1.0092878e+00 9.9380815e-01 6.1904558e-04 2.8607893e-01
#   0.0000000e+00 0.0000000e+00]
#  [9.9569499e-01 1.0061501e+00 9.9569499e-01 6.8113692e-03 2.3222871e-01
#   1.0000000e+00 1.0000000e+00]]
# done, truncated, action, reward False False 1 -0.000614215091590366
# info {'idx': 8, 'step': 6, 'date': Timestamp('1963-01-11 00:00:00-0500', tz='UTC-05:00'), 'position_index': 1, 'position': 1, 'real_position': 1.0, 'data_typical': 1.0856312478002346, 'data_median': 1.0839620775604897, 'data_high': 1.088969588279724, 'data_low': 1.0789545668412552, 'data_open': 1.0856311811972683, 'data_volume': 6739857.482617016, 'data_close': 1.088969588279724, 'portfolio_valuation': 1013.2576278563672, 'portfolio_distribution_asset': 933.3349882010906, 'portfolio_distribution_fiat': 0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': -0.000614215091590366}
# observation [[9.9938071e-01 1.0092878e+00 9.9380815e-01 6.1904558e-04 2.8607893e-01
#   0.0000000e+00 0.0000000e+00]
#  [9.9569499e-01 1.0061501e+00 9.9569499e-01 6.8113692e-03 2.3222871e-01
#   1.0000000e+00 1.0000000e+00]
#  [9.9693435e-01 1.0000000e+00 9.9080324e-01 3.0756800e-03 2.0193788e-01
#   1.0000000e+00 1.0000000e+00]]
# done, truncated, action, reward False False 1 0.01404461730887553
# info {'idx': 9, 'step': 7, 'date': Timestamp('1963-01-14 00:00:00-0500', tz='UTC-05:00'), 'position_index': 1, 'position': 1, 'real_position': 1.0, 'data_typical': 1.1009860973106091, 'data_median': 1.0983154387095964, 'data_high': 1.1076628353920892, 'data_low': 1.0889680420271035, 'data_open': 1.0889680420271035, 'data_volume': 12356422.92996307, 'data_close': 1.1063274145126345, 'portfolio_valuation': 1027.5888461429622, 'portfolio_distribution_asset': 933.3349882010906, 'portfolio_distribution_fiat': 0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': 0.01404461730887553}
# observation [[0.995695   1.0061501  0.995695   0.00681137 0.23222871 1.
#   1.        ]
#  [0.99693435 1.         0.99080324 0.00307568 0.20193788 1.
#   1.        ]
#  [0.984309   1.0012071  0.984309   0.01593968 0.37022    1.
#   1.        ]]
# done, truncated, action, reward False False 1 0.007050539002840737
# info {'idx': 10, 'step': 8, 'date': Timestamp('1963-01-15 00:00:00-0500', tz='UTC-05:00'), 'position_index': 1, 'position': 1, 'real_position': 1.0, 'data_typical': 1.1087760722222464, 'data_median': 1.1089986258123123, 'data_high': 1.1163430940931909, 'data_low': 1.1016541575314338, 'data_open': 1.10632788282717, 'data_volume': 10409345.81951381, 'data_close': 1.1083309650421145, 'portfolio_valuation': 1034.8595022852019, 'portfolio_distribution_asset': 933.3349882010906, 'portfolio_distribution_fiat': 0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': 0.007050539002840737}
# observation [[0.99693435 1.         0.99080324 0.00307568 0.20193788 1.
#   1.        ]
#  [0.984309   1.0012071  0.984309   0.01593968 0.37022    1.
#   1.        ]
#  [0.9981927  1.007229   0.9939758  0.00181099 0.31188217 1.
#   1.        ]]
# done, truncated, action, reward False False 1 -0.012522625459798242
# info {'idx': 11, 'step': 9, 'date': Timestamp('1963-01-16 00:00:00-0500', tz='UTC-05:00'), 'position_index': 1, 'position': 1, 'real_position': 1.0, 'data_typical': 1.094977859987672, 'data_median': 1.0969808762279984, 'data_high': 1.1069958908267103, 'data_low': 1.0869658616292868, 'data_open': 1.1069958908267103, 'data_volume': 6327981.624817589, 'data_close': 1.090971827507019, 'portfolio_valuation': 1021.9811480320493, 'portfolio_distribution_asset': 933.3349882010906, 'portfolio_distribution_fiat': 0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': -0.012522625459798242}
# observation [[ 0.984309    1.0012071   0.984309    0.01593968  0.37022     1.
#    1.        ]
#  [ 0.9981927   1.007229    0.9939758   0.00181099  0.31188217  1.
#    1.        ]
#  [ 1.0146879   1.0146879   0.99632806 -0.01566241  0.18959737  1.
#    1.        ]]
# done, truncated, action, reward False False 1 0.006281080329451108
# info {'idx': 12, 'step': 10, 'date': Timestamp('1963-01-17 00:00:00-0500', tz='UTC-05:00'), 'position_index': 1, 'position': 1, 'real_position': 1.0, 'data_typical': 1.1018771486959922, 'data_median': 1.1003192897859315, 'data_high': 1.107663610238988, 'data_low': 1.0929749693328752, 'data_open': 1.0929749693328752, 'data_volume': 6065876.104154854, 'data_close': 1.1049928665161133, 'portfolio_valuation': 1028.4204955772252, 'portfolio_distribution_asset': 933.3349882010906, 'portfolio_distribution_fiat': 0, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': 0.006281080329451108}
# observation [[ 0.9981927   1.007229    0.9939758   0.00181099  0.31188217  1.
#    1.        ]
#  [ 1.0146879   1.0146879   0.99632806 -0.01566241  0.18959737  1.
#    1.        ]
#  [ 0.989124    1.002417    0.989124    0.01285188  0.18174423  1.
#    1.        ]]
# done, truncated, action, reward False False 0 -0.00010000500033334732
# info {'idx': 13, 'step': 11, 'date': Timestamp('1963-01-18 00:00:00-0500', tz='UTC-05:00'), 'position_index': 0, 'position': 0, 'real_position': 0.0, 'data_typical': 1.1025448108353544, 'data_median': 1.102989951467265, 'data_high': 1.1096666613283892, 'data_low': 1.0963132416061407, 'data_open': 1.1049929344542873, 'data_volume': 4268579.218256904, 'data_close': 1.1016545295715332, 'portfolio_valuation': 1028.3176535276675, 'portfolio_distribution_asset': 0, 'portfolio_distribution_fiat': 1028.3176535276675, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': -0.00010000500033334732}
# observation [[ 1.0146879   1.0146879   0.99632806 -0.01566241  0.18959737  1.
#    1.        ]
#  [ 0.989124    1.002417    0.989124    0.01285188  0.18174423  1.
#    1.        ]
#  [ 1.0030303   1.0072728   0.9951516  -0.00302114  0.12789409  0.
#    0.        ]]
# Market Return :  4.41%   |   Portfolio Return :  2.83%   |   Position Changes : 4   |   Episode Lenght : 13   |
# done, truncated, action, reward False True 0 0.0
# info {'idx': 14, 'step': 12, 'date': Timestamp('1963-01-21 00:00:00-0500', tz='UTC-05:00'), 'position_index': 0, 'position': 0, 'real_position': 0.0, 'data_typical': 1.100764277816938, 'data_median': 1.0983161378519632, 'data_high': 1.1056605577468872, 'data_low': 1.0909717179570393, 'data_open': 1.1016543924626718, 'data_volume': 4380910.79555228, 'data_close': 1.1056605577468872, 'portfolio_valuation': 1028.3176535276675, 'portfolio_distribution_asset': 0, 'portfolio_distribution_fiat': 1028.3176535276675, 'portfolio_distribution_borrowed_asset': 0, 'portfolio_distribution_borrowed_fiat': 0, 'portfolio_distribution_interest_asset': 0.0, 'portfolio_distribution_interest_fiat': 0.0, 'reward': 0.0}
# observation [[ 0.989124    1.002417    0.989124    0.01285188  0.18174423  1.
#    1.        ]
#  [ 1.0030303   1.0072728   0.9951516  -0.00302114  0.12789409  0.
#    0.        ]
#  [ 0.9963767   1.          0.9867149   0.00363637  0.13125974  0.
#    0.        ]]
# c:\Users\Binck\anaconda3\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.add_metric to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.add_metric` for environment variables or `env.get_wrapper_attr('add_metric')` that will search the reminding wrappers.
#   logger.warn(
